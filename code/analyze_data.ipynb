# %% [markdown]
# # Import libary that essential

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## read data from file

# %%
data = pd.read_csv('./../data/Madrid Daily Weather 1997-2015.csv')
data.head()
# Out:
#           CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  1997-01-01               7.0                4.0               2.0
# 1  1997-01-02               7.0                3.0               0.0
# 2  1997-01-03               5.0                3.0               2.0
# 3  1997-01-04               7.0                3.0              -1.0
# 4  1997-01-05               2.0                0.0              -1.0
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 0         5.0             3.0            2.0         100.0            95.0
# 1         6.0             3.0            0.0         100.0            92.0
# 2         5.0             1.0           -1.0         100.0            85.0
# 3        -2.0            -3.0           -4.0          86.0            63.0
# 4         2.0             0.0           -3.0         100.0            95.0
#
#     Min Humidity  ...   Max VisibilityKm   Mean VisibilityKm  \
# ...

# %% [markdown]
# ## Modify data

# %%
data.columns = data.columns.str.strip()

# %% [markdown]
# ## Detail of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6812 entries, 0 to 6811
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CET                         6812 non-null   object
#  1   Max TemperatureC            6810 non-null   float64
#  2   Mean TemperatureC           6809 non-null   float64
#  3   Min TemperatureC            6810 non-null   float64
#  4   Dew PointC                  6810 non-null   float64
#  5   MeanDew PointC              6810 non-null   float64
#  6   Min DewpointC               6810 non-null   float64
#  7   Max Humidity                6810 non-null   float64
#  8   Mean Humidity               6810 non-null   float64
#  9   Min Humidity                6810 non-null   float64
#  10  Max Sea Level PressurehPa   6812 non-null   int64
#  11  Mean Sea Level PressurehPa  6812 non-null   int64
#  12  Min Sea Level PressurehPa   6812 non-null   int64
# ...

# %%
data.describe()
# Out:
#        Max TemperatureC  Mean TemperatureC  Min TemperatureC   Dew PointC  \
# count       6810.000000        6809.000000       6810.000000  6810.000000
# mean          21.039648          14.658687          8.640529     8.120705
# std            8.867187           7.580461          6.837626     4.741067
# min            0.000000          -3.000000        -10.000000   -12.000000
# 25%           13.000000           8.000000          3.000000     5.000000
# 50%           20.000000          14.000000          9.000000     8.000000
# 75%           29.000000          21.000000         14.000000    12.000000
# max           41.000000          32.000000         28.000000    20.000000
#
#        MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# count     6810.000000    6810.000000   6810.000000    6810.000000
# mean         4.976211       1.451248     81.139354      57.971366
# std          4.654270       4.909705     17.531839      19.675744
# ...

# %% [markdown]
# ## Split Cell

# %%
# data.columns = ['Date', 'Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC', 'Max DewPointC', 'Mean DewPointC', 'Min DewPointC', 'Max Humidity', 'Mean Humidity', 'Min Humidity', 'Max SLP', 'Mean SLP', 'Min SLP', 'Max VisibilityKm', 'Mean VisibilityKm', 'Min VisibilitykM', 'Max Wind SpeedKm/h', 'Mean Wind SpeedKm/h', 'Max Gust SpeedKm/h', 'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees']
# data

# %%
# temperature_data = data[['Max TemperatureC','Mean TemperatureC','Min TemperatureC']]
# temperature_data.corr()

# %%
# dew_point_data = data[['Dew PointC','MeanDew PointC','Min DewpointC']]
# dew_point_data.columns = ['Max DewPointC','Mean DewPointC','Min DewPointC']
# dew_point_data.corr()

# %%
# humidity_data = data[['Max Humidity', 'Mean Humidity', 'Min Humidity']]
# humidity_data.corr()

# %%
# sea_level = data[['Max Sea Level PressurehPa', 'Mean Sea Level PressurehPa', 'Min Sea Level PressurehPa']]
# sea_level.columns = ['Max SLP', 'Mean SLP', 'Min SLP']
# sea_level

# %%
# visbility_data = data[['Max VisibilityKm', 'Mean VisibilityKm', 'Min VisibilitykM']]
# visbility_data

# %% [markdown]
# ## Cleaning data
# - fill missing data
# - handling outliers
# - distinguishing and fixing errors present in the dataset

# %% [markdown]
# ### Cleaning data cycle
# - merge data set
# - rebuild missing data
# - standardize
# - normalize
# - de-duplicate
# - verify and enrich

# %% [markdown]
# ### Type of invalid data
# - messy data
# - missing value
# - nonsensical data

# %%
# convert object type to datetimes type
data['CET'] = pd.to_datetime(data['CET'])
data
# Out:
#             CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0    1997-01-01               7.0                4.0               2.0
# 1    1997-01-02               7.0                3.0               0.0
# 2    1997-01-03               5.0                3.0               2.0
# 3    1997-01-04               7.0                3.0              -1.0
# 4    1997-01-05               2.0                0.0              -1.0
# ...         ...               ...                ...               ...
# 6807 2015-12-27              14.0                7.0              -1.0
# 6808 2015-12-28              15.0                8.0               2.0
# 6809 2015-12-29              11.0                8.0               5.0
# 6810 2015-12-30               9.0                8.0               6.0
# 6811 2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# ...

# %%
# select year from 2005 - 2015 that we interest
focus_data = data[(data['CET'] >= '2005-01-01')]
focus_data
# Out:
#             CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 2795 2005-01-01              12.0                4.0              -2.0
# 2796 2005-01-02              14.0                6.0              -2.0
# 2797 2005-01-03              11.0                4.0              -2.0
# 2798 2005-01-04              10.0                3.0              -3.0
# 2799 2005-01-05              10.0                3.0              -4.0
# ...         ...               ...                ...               ...
# 6807 2015-12-27              14.0                7.0              -1.0
# 6808 2015-12-28              15.0                8.0               2.0
# 6809 2015-12-29              11.0                8.0               5.0
# 6810 2015-12-30               9.0                8.0               6.0
# 6811 2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# ...

# %%
# group data by year
focus_data_year = focus_data.groupby(focus_data.CET.dt.year)
a = focus_data_year['Mean TemperatureC'].mean()
plt.figure(figsize=[10,8])
plt.bar(bin_edges[:-1], hist, width = 0.5, color='#0504aa',alpha=0.7)
plt.xlim(min(bin_edges), max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.title('Normal Distribution Histogram',fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       3 a = focus_data_year['Mean TemperatureC'].mean()
#       4 plt.figure(figsize=[10,8])
# ----> 5 plt.bar(bin_edges[:-1], hist, width = 0.5, color='#0504aa',alpha=0.7)
#       6 plt.xlim(min(bin_edges), max(bin_edges))
#       7 plt.grid(axis='y', alpha=0.75)
#
# NameError: name 'bin_edges' is not defined

# %%
focus_data_month = data[(data['CET'] >= '2015-01-01')]
focus_data_month = focus_data_month.groupby(focus_data_month.CET.dt.month)
focus_data_month['Mean TemperatureC'].mean()
# Out:
# CET
# 1      5.161290
# 2      6.464286
# 3     10.516129
# 4     14.066667
# 5     19.451613
# 6     23.633333
# 7     28.806452
# 8     25.290323
# 9     20.033333
# 10    15.612903
# 11    11.600000
# 12     8.290323
# Name: Mean TemperatureC, dtype: float64

# %%
focus_data_month['Max TemperatureC'].mean()
# Out:
# CET
# 1     11.903226
# 2     11.464286
# 3     17.354839
# 4     20.700000
# 5     27.354839
# 6     31.400000
# 7     36.903226
# 8     32.741935
# 9     27.066667
# 10    21.161290
# 11    18.233333
# 12    14.451613
# Name: Max TemperatureC, dtype: float64

# %%
focus_data_month['Min TemperatureC'].mean()
# Out:
# CET
# 1     -1.483871
# 2      1.785714
# 3      3.677419
# 4      7.466667
# 5     11.451613
# 6     15.833333
# 7     20.612903
# 8     17.967742
# 9     13.033333
# 10    10.161290
# 11     5.000000
# 12     2.032258
# Name: Min TemperatureC, dtype: float64

# %% [markdown]
# ## Manage outlier data

# %%
#test

# %%
focus_data.describe()
# Out:
#                        CET  Max TemperatureC  Mean TemperatureC  \
# count                  365        365.000000          365.00000
# mean   2015-07-02 00:00:00         22.632877           15.80274
# min    2015-01-01 00:00:00          4.000000            1.00000
# 25%    2015-04-02 00:00:00         15.000000            9.00000
# 50%    2015-07-02 00:00:00         22.000000           16.00000
# 75%    2015-10-01 00:00:00         30.000000           22.00000
# max    2015-12-31 00:00:00         40.000000           31.00000
# std                    NaN          8.846183            7.84461
#
#        Min TemperatureC  Dew PointC  MeanDew PointC  Min DewpointC  \
# count        365.000000  365.000000      365.000000     365.000000
# mean           9.005479    8.369863        5.109589       1.449315
# min           -6.000000   -4.000000       -7.000000     -12.000000
# 25%            3.000000    6.000000        2.000000      -2.000000
# ...

# %% [markdown]
# ## Analysis data

# %% [markdown]
# ### topic
# - how different of data in range between 10 year
# - what is pattern of temperature in each year
# - Max temperature average in a year
# - Min temperature average in a year
# -

# %% [markdown]
# ## test

# %% [markdown]
# ## useful link
# - https://www.analyticsvidhya.com/blog/2021/06/data-cleaning-using-pandas/#What_Is_Data_Cleaning? (cleaning data)
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html (pandas school)
